# %%
# EXAMPLE OF COMMAND TO DOWNLOAD DATA

# !wget -q --show-progress \
# [URL] \
# -O ../data/[NAME]

# %%
# F04__T_data.mat
# !wget -q --show-progress \
"https://ufmgbr-my.sharepoint.com/personal/matheusvra_ufmg_br/_layouts/15/download.aspx?UniqueId=e484831b-0103-4779-95ae-569eb269066b" \
-O ../data/F04__T_data.mat

# %%
# data_matrix.csv
# !wget -q --show-progress \
"https://ufmgbr-my.sharepoint.com/personal/matheusvra_ufmg_br/_layouts/15/download.aspx?UniqueId=82518b4e-5e57-4df8-bec0-7bb69c9ecbc4" \
-O ../data/data_matrix.csv

# %%
# events_behavior_TS_LFPindex.csv
# !wget -q --show-progress \
"https://ufmgbr-my.sharepoint.com/personal/matheusvra_ufmg_br/_layouts/15/download.aspx?UniqueId=77244d44-39e5-40de-a0cd-11f7914eca7f" \
-O ../data/events_behavior_TS_LFPindex.csv

# %%
# events_behavior_TS_LFPsec.csv
# !wget -q --show-progress \
"https://ufmgbr-my.sharepoint.com/personal/matheusvra_ufmg_br/_layouts/15/download.aspx?UniqueId=ced3e1b1-f8a0-43af-b7a0-8518cd33a76d" \
-O ../data/events_behavior_TS_LFPsec.csv

# %%
# events_index.csv
# !wget -q --show-progress \
"https://ufmgbr-my.sharepoint.com/personal/matheusvra_ufmg_br/_layouts/15/download.aspx?UniqueId=cfb1a84d-f889-4b11-9005-1c037a3d7cbd" \
-O ../data/events_index.csv

# %%
# events_index_timestamp.csv
# !wget -q --show-progress \
"https://ufmgbr-my.sharepoint.com/personal/matheusvra_ufmg_br/_layouts/15/download.aspx?UniqueId=2ad9ee43-9fdd-44ef-9b8f-52a55e299a80" \
-O ../data/events_index_timestamp.csv
