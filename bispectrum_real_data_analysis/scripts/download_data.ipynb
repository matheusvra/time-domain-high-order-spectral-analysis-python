# %%
# EXAMPLE OF COMMAND TO DOWNLOAD DATA

# !wget -q --show-progress \
# [URL] \
# -O ../data/[NAME]

# %%
# F04__T_data.mat
# !wget -q --show-progress \
"https://www.dropbox.com/s/1sktixq8e55kchf/F04__T_data.mat?dl=0" \
-O ../data/F04__T_data.mat
# Out:
# ../data/F04__T_data 100%[===================>] 120,43M  27,1MB/s    in 5,1s

# %%
# data_matrix.csv
# !wget -q --show-progress \
"https://www.dropbox.com/s/6j8mg6dysmxifa1/data_matrix.csv?dl=0" \
-O ../data/data_matrix.csv
# Out:
# ../data/data_matrix 100%[===================>] 167,49M  27,1MB/s    in 6,9s

# %%
# events_behavior_TS_LFPindex.csv
# !wget -q --show-progress \
"https://www.dropbox.com/s/gc7jx2ydfyg825p/events_behavior_TS_LFPindex.csv?dl=0" \
-O ../data/events_behavior_TS_LFPindex.csv
# Out:
# ../data/events_beha 100%[===================>]     152  --.-KB/s    in 0s

# %%
# events_behavior_TS_LFPsec.csv
# !wget -q --show-progress \
"https://www.dropbox.com/s/ramy6psfxl62jav/events_behavior_TS_LFPsec.csv?dl=0" \
-O ../data/events_behavior_TS_LFPsec.csv
# Out:
# ../data/events_beha 100%[===================>]     170  --.-KB/s    in 0s

# %%
# events_index.csv
# !wget -q --show-progress \
"https://www.dropbox.com/s/lmu7sce74te3axf/events_index.csv?dl=0" \
-O ../data/events_index.csv
# Out:
# ../data/events_inde 100%[===================>]      80  --.-KB/s    in 0s

# %%
# events_index_timestamp.csv
# !wget -q --show-progress \
"https://www.dropbox.com/s/83edt7ao6ok6q05/events_index_timestamp.csv?dl=0" \
-O ../data/events_index_timestamp.csv
# Out:
# ../data/events_inde 100%[===================>]      98  --.-KB/s    in 0s
